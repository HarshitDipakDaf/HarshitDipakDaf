# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/91914/Downloads/Data_companies/companies.csv")

# %%
df.head()
# Out:
#         id  Unnamed: 0.1 entity_type  entity_id  parent_id  \
# 0      c:1             0     Company          1        NaN
# 1     c:10             1     Company         10        NaN
# 2    c:100             2     Company        100        NaN
# 3  c:10000             3     Company      10000        NaN
# 4  c:10001             4     Company      10001        NaN
#
#                  name     normalized_name                    permalink  \
# 0            Wetpaint            wetpaint            /company/wetpaint
# 1             Flektor             flektor             /company/flektor
# 2               There               there               /company/there
# 3             MYWEBBO             mywebbo             /company/mywebbo
# 4  THE Movie Streamer  the movie streamer  /company/the-movie-streamer
#
#      category_code     status  ... first_milestone_at last_milestone_at  \
# 0              web  operating  ...         2010-09-05        2013-09-18
# ...

# %%
#Step 1: Checking the percentage of NaN (null) values present in each feature
nan_percentage = df.isnull().mean() * 100
print("Percentage of NaN values in each feature:\n", nan_percentage)
# Out:
# Percentage of NaN values in each feature:
#  id                       0.000000
# Unnamed: 0.1             0.000000
# entity_type              0.000000
# entity_id                0.000000
# parent_id              100.000000
# name                     0.011193
# normalized_name          0.013228
# permalink                0.000000
# category_code           37.326828
# status                   0.000000
# founded_at              53.586564
# closed_at               98.667026
# domain                  35.617874
# homepage_url            35.617874
# twitter_username        58.997828
# logo_url                43.979486
# logo_width              43.979486
# logo_height             43.979486
# short_description       96.371971
# description             53.168865
# overview                35.401139
# tag_list                58.559778
# country_code            55.233448
# state_code              74.102151
# city                    57.319400
# region                   0.000000
# ...

# %%
# Step 2: Removing duplicates
df = df.drop_duplicates()

# %%
# Step 3: Dropping columns which have NaN values
threshold = 50  
columns_to_drop = nan_percentage[nan_percentage > threshold].index
df = df.drop(columns=columns_to_drop)

# %%
# Step 4: Remove unnecessary and corrupted data
# Assuming unnecessary columns are identified
unnecessary_columns = ['normalized_name', 'entity_id', 'short_description']
df = df.drop(columns=unnecessary_columns, errors='ignore')  # 'errors' set to ignore in case columns are already dropped

# %%
# Step 5: Data Labelling 
# Labeling target variable 'status' to numerical values
status_mapping = {'Operating': 0, 'IPO': 1, 'Acquired': 2, 'Closed': 3}
df['status'] = df['status'].map(status_mapping)

# %%
df.head(10)
# Out:
#          id  Unnamed: 0.1 entity_type  entity_id  \
# 0       c:1             0     Company          1
# 1      c:10             1     Company         10
# 2     c:100             2     Company        100
# 3   c:10000             3     Company      10000
# 4   c:10001             4     Company      10001
# 5   c:10002             5     Company      10002
# 6   c:10003             6     Company      10003
# 7  c:100042             7     Company     100042
# 8   c:10005             8     Company      10005
# 9  c:100062             9     Company     100062
#
#                             name                normalized_name  \
# 0                       Wetpaint                       wetpaint
# 1                        Flektor                        flektor
# 2                          There                          there
# 3                        MYWEBBO                        mywebbo
# 4             THE Movie Streamer             the movie streamer
# ...
